# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavodgomez-2026/ejercicios-python/blob/main/Copy_of_Ejercicio3_GGA4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio 3 — Ecosistema IA: Pipelines, APIs y RAG
#
# **Módulo: Python para IA** | Máster en Inteligencia Artificial
#
# **Tipo**: Autoevaluable | **Sesión**: 3
# **Fecha límite**: Antes de la Sesión 4
#
# ---
#
# ### Instrucciones
#
# 1. **Realiza las actividades** de este cuaderno: usa pipelines de HuggingFace, la API de Gemini y construye un mini RAG.
# 2. Necesitarás una **API Key de Gemini** (gratuita): [aistudio.google.com/apikey](https://aistudio.google.com/apikey)
# 3. Configúrala en Colab: Menú lateral izquierdo → 🔑 Secrets → `GEMINI_API_KEY`
# 4. Las celdas de validación te ayudarán a saber si vas bien ✅
# 5. **Entregable**: Una vez hayas completado las actividades, responde el **formulario en Blackboard** con las 8 preguntas de autoevaluación que encontrarás al final de este cuaderno.

# %% [markdown]
# ---
# ## Parte A — HuggingFace Pipelines (35 puntos)
#
# ### A.1 — Análisis de sentimiento en lote (15 pts)
#
# Usa el pipeline de `sentiment-analysis` para clasificar las siguientes reseñas.
# Cuenta cuántas son POSITIVE y cuántas NEGATIVE.

# %%
from transformers import pipeline

# Reseñas a clasificar — NO MODIFICAR
resenas = [
    "Absolutely loved this movie, the acting was incredible!",
    "Waste of time, terrible plot and boring characters.",
    "Great product, works exactly as described. Very happy!",
    "The service was awful, waited 2 hours for cold food.",
    "Beautiful design, intuitive interface, highly recommend.",
    "Not bad but nothing special. Average quality overall.",
    "This is the best purchase I've made this year!",
    "Completely broken on arrival, worst experience ever.",
    "Decent value for the price, does what it promises.",
    "Mind-blowing performance, exceeded all my expectations!"
]

# %%
clasificador = pipeline("sentiment-analysis", model="cardiffnlp/twitter-roberta-base-sentiment-latest")

num_positivas = 0
num_negativas = 0

for resena in resenas:
    resultado = clasificador(resena)[0] # El pipeline devuelve una lista de un solo diccionario
    # The model 'cardiffnlp/twitter-roberta-base-sentiment-latest' outputs 'negative', 'neutral', 'positive'
    # We'll count 'positive' as POSITIVE and 'negative' as NEGATIVE for this exercise.
    if resultado['label'] == 'positive':
        num_positivas += 1
    elif resultado['label'] == 'negative':
        num_negativas += 1

print(f"Positivas: {num_positivas}")
print(f"Negativas: {num_negativas}")
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-sentiment-latest
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.pooler.dense.weight     | UNEXPECTED |  |
# roberta.embeddings.position_ids | UNEXPECTED |  |
# roberta.pooler.dense.bias       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Positivas: 6
# Negativas: 4

# %%
# Validación A.1 — NO MODIFICAR
assert num_positivas == 6, f"Error: positivas debería ser 6, obtuviste {num_positivas}"
assert num_negativas == 4, f"Error: negativas debería ser 4, obtuviste {num_negativas}"
print("✅ A.1 — Sentimiento: CORRECTO")
# Out:
# ✅ A.1 — Sentimiento: CORRECTO

# %% [markdown]
# ### A.2 — Zero-shot classification (20 pts)
#
# Clasifica los siguientes textos en categorías usando `zero-shot-classification`. Para cada texto, indica cuál es la categoría con mayor score.

# %%
# Textos a clasificar — NO MODIFICAR
textos = [
    "The new Tesla Model Y achieved record sales in Q3 2024",
    "Barcelona won the Champions League final 3-1",
    "NASA discovered a potentially habitable exoplanet",
    "The stock market reached an all-time high today",
    "New study shows Mediterranean diet reduces heart disease risk"
]
categorias = ["technology", "sports", "science", "finance", "health"]

# %%
# Textos a clasificar — NO MODIFICAR
textos = [
    "The new Tesla Model Y achieved record sales in Q3 2024",
    "Barcelona won the Champions League final 3-1",
    "NASA discovered a potentially habitable exoplanet",
    "The stock market reached an all-time high today",
    "New study shows Mediterranean diet reduces heart disease risk"
]
categorias = ["technology", "sports", "science", "finance", "health"]

# Using a more advanced model for zero-shot classification
clasificador_zs = pipeline("zero-shot-classification", model="typeform/distilbert-base-uncased-mnli")

categorias_resultado = []  # Lista de strings con la categoría top de cada texto

for texto in textos:
    resultado = clasificador_zs(texto, candidate_labels=categorias)
    # The result contains 'labels' and 'scores', we want the label with the highest score (first one)
    categorias_resultado.append(resultado['labels'][0])

print(f"Categorías: {categorias_resultado}")
# Out:
# config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/258 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Categorías: ['technology', 'sports', 'science', 'finance', 'health']

# %%
# Validación A.2 — NO MODIFICAR
expected = ["technology", "sports", "science", "finance", "health"]
assert categorias_resultado == expected, f"Error: esperado {expected}, obtuviste {categorias_resultado}"
print("✅ A.2 — Zero-shot: CORRECTO")
# Out:
# ✅ A.2 — Zero-shot: CORRECTO

# %% [markdown]
# ---
# ## Parte B — API de Gemini (30 puntos)
#
# ### B.1 — Generar resúmenes (15 pts)
#
# Usa la API de Gemini para generar un resumen de un texto dado. Extrae información específica del resultado.

# %%
import google.generativeai as genai
from google.colab import userdata

genai.configure(api_key=userdata.get("GEMINI_API_KEY"))

# Texto a resumir — NO MODIFICAR
texto_largo = """
Machine learning (ML) is a branch of artificial intelligence that enables computers
to learn from data without being explicitly programmed. There are three main types
of machine learning: supervised learning, unsupervised learning, and reinforcement
learning. Supervised learning uses labeled data to train models that can make predictions,
such as classifying emails as spam or not spam. Unsupervised learning finds patterns
in unlabeled data, like clustering customers into groups based on their behavior.
Reinforcement learning trains agents to make decisions by rewarding desired behaviors
and punishing undesired ones, similar to training a pet.

Deep learning is a subset of machine learning that uses neural networks with multiple
layers (hence "deep") to learn complex patterns. Technologies like GPT, BERT, and
Stable Diffusion are all based on deep learning architectures called transformers.
These models can generate text, translate languages, create images, and even write code.

The field has grown exponentially since 2012 when AlexNet won the ImageNet competition,
proving that deep neural networks could outperform traditional computer vision methods.
Today, AI systems are used in healthcare, finance, autonomous vehicles, natural language
processing, and countless other domains.
"""

# %%
# B.1 — Usa Gemini para extraer los 3 tipos de machine learning mencionados

model = genai.GenerativeModel("gemini-2.5-flash")

# Tu prompt aquí — pide a Gemini que extraiga los 3 tipos de ML
# El resultado debe ser una lista de strings: ["supervised", "unsupervised", "reinforcement"]

prompt = f"""Del siguiente texto, extrae los tres tipos principales de machine learning mencionados. Responde únicamente con una lista de Python de strings. El texto es:
\"\"\"\n{texto_largo}
\"\"\""""

response = model.generate_content(prompt)

# Assuming Gemini returns a string that can be evaluated as a Python list
# Clean up the response text by removing markdown code block wrappers if present
cleaned_response_text = response.text.replace('```python', '').replace('```', '').strip()
tipos_ml = eval(cleaned_response_text)

print(f"Tipos de ML: {tipos_ml}")
# Out:
# Tipos de ML: ['supervised learning', 'unsupervised learning', 'reinforcement learning']

# %%
# Validación B.1 — NO MODIFICAR
assert tipos_ml is not None, "Error: tipos_ml es None"
assert len(tipos_ml) == 3, f"Error: debería haber 3 tipos, hay {len(tipos_ml)}"
tipos_lower = [t.lower().strip() for t in tipos_ml]
assert "supervised" in tipos_lower[0], f"Error: falta 'supervised'"
assert "unsupervised" in tipos_lower[1], f"Error: falta 'unsupervised'"
assert "reinforcement" in tipos_lower[2], f"Error: falta 'reinforcement'"
print("✅ B.1 — Extracción con Gemini: CORRECTO")
# Out:
# ✅ B.1 — Extracción con Gemini: CORRECTO

# %% [markdown]
# ### B.2 — Chat multi-turno (15 pts)
#
# Crea un chat con Gemini que:
# 1. Le preguntes "¿Qué es Python?" → Guarda la respuesta.
# 2. Le preguntes "¿Y cuáles son sus principales ventajas?" → Guarda la respuesta.
# 3. Le preguntes "Resume todo lo anterior en una frase" → Guarda la respuesta.
#
# Verifica que el chat mantiene el contexto.

# %%
import google.generativeai as genai
from google.colab import userdata

genai.configure(api_key=userdata.get("GEMINI_API_KEY"))

model = genai.GenerativeModel("gemini-2.5-flash")
chat = model.start_chat(history=[])

# Tu código aquí — haz las 3 preguntas y guarda cada respuesta

respuesta_1 = chat.send_message("¿Qué es Python?").text
respuesta_2 = chat.send_message("¿Y cuáles son sus principales ventajas?").text
respuesta_3 = chat.send_message("Resume todo lo anterior en una frase").text

num_mensajes_historial = len(chat.history)

print(f"Respuesta 1 (¿Qué es Python?): {respuesta_1}\n")
print(f"Respuesta 2 (Ventajas de Python?): {respuesta_2}\n")
print(f"Respuesta 3 (Resumen): {respuesta_3}\n")
print(f"Mensajes en historial: {num_mensajes_historial}")
# Out:
# Respuesta 1 (¿Qué es Python?): **Python es un lenguaje de programación de alto nivel, interpretado, de propósito general y muy popular, conocido por su sintaxis clara y legible, lo que lo hace muy fácil de aprender y usar.**
#
# Aquí desglosamos sus características principales:
#
# 1.  **De Alto Nivel:** Significa que Python se abstrae de los detalles de bajo nivel del hardware de la computadora (como la gestión de memoria). Esto permite a los programadores centrarse más en la lógica del programa y menos en cómo la máquina ejecuta las instrucciones. Su sintaxis es más cercana al lenguaje humano.
#
# 2.  **Interpretado:** A diferencia de los lenguajes compilados (como C++ o Java), el código Python se ejecuta directamente línea por línea por un intérprete. No requiere un paso de compilación separado antes de la ejecución, lo que acelera el ciclo de desarrollo y prueba.
#
# 3.  **De Propósito General:** Esto significa que Python no está diseñado para un tipo específico de aplicación. Puede ser utilizado para una amplia variedad de tareas y en muchos dominios diferentes.
#
# 4.  **Sintaxis Clara y Legible:** Python fue diseñado con la legibilidad en mente. Su sintaxis se parece mucho al inglés y utiliza indentación (espacios o tabulaciones) para definir bloques de código, lo que fomenta un código limpio y organizado. Es ideal para principiantes en programación.
#
# 5.  **Multiplataforma:** El código Python puede ejecutarse en diferentes sistemas operativos (Windows, macOS, Linux) con pocas o ninguna modificación.
#
# 6.  **Gran Biblioteca Estándar y Ecosistema Extenso:** Python viene con una vasta colección de módulos y paquetes preconstruidos ("pilas incluidas") que permiten realizar una gran cantidad de tareas sin necesidad de escribir mucho código desde cero. Además, su comunidad ha desarrollado miles de librerías de terceros (como NumPy, Pandas para datos; Django, Flask para web; TensorFlow, PyTorch para Machine Learning) que extienden enormemente sus capacidades.
#
# **¿Para qué se utiliza Python?**
#
# Debido a su versatilidad y sus potentes librerías, Python se utiliza en una multitud de áreas:
#
# *   **Desarrollo Web:** Con frameworks como Django y Flask, se usa para construir sitios web dinámicos y aplicaciones web robustas.
# *   **Ciencia de Datos y Análisis:** Es la herramienta principal para análisis de datos, visualización y manipulación, gracias a librerías como Pandas, NumPy y Matplotlib.
# *   **Inteligencia Artificial y Machine Learning:** Librerías como TensorFlow, Keras y PyTorch lo hacen indispensable para desarrollar modelos de IA y aprendizaje automático.
# *   **Automatización y Scripting:** Es excelente para automatizar tareas repetitivas, gestionar sistemas y crear scripts utilitarios.
# *   **Desarrollo de Software:** Se usa para crear aplicaciones de escritorio (con PyQt o Tkinter), herramientas de línea de comandos, etc.
# *   **Educación:** Es uno de los lenguajes más populares para enseñar programación debido a su simplicidad y legibilidad.
# *   **Computación Científica:** Utilizado en campos como la física, la biología y las matemáticas para simulación y modelado.
# *   **Juegos:** Aunque no es su uso principal, con librerías como Pygame, se pueden desarrollar juegos.
#
# En resumen, Python es un lenguaje de programación muy potente, flexible y amigable, que se ha convertido en una de las herramientas más demandadas en el mundo de la tecnología gracias a su facilidad de uso, su inmensa comunidad y su capacidad para abordar casi cualquier tipo de proyecto.
#
# Respuesta 2 (Ventajas de Python?): Python se ha ganado su inmensa popularidad gracias a una serie de **ventajas clave** que lo hacen atractivo para desarrolladores de todos los niveles y para una vasta gama de aplicaciones. Aquí te detallo las principales:
#
# 1.  **Facilidad de Aprendizaje y Legibilidad del Código:**
#     *   **Sintaxis Clara y Concisa:** La sintaxis de Python es muy intuitiva y se asemeja al lenguaje natural (inglés). Esto reduce la curva de aprendizaje para principiantes y facilita la lectura y comprensión del código existente, incluso si fue escrito por otra persona.
#     *   **Fomenta el Código Limpio:** El uso obligatorio de la indentación para definir bloques de código obliga a los desarrolladores a escribir código bien estructurado y legible, lo que mejora la mantenibilidad.
#
# 2.  **Versatilidad y Amplio Campo de Aplicación (Propósito General):**
#     *   Python puede ser utilizado para casi cualquier cosa: desarrollo web, ciencia de datos, inteligencia artificial, machine learning, automatización de tareas (scripting), desarrollo de software de escritorio, aplicaciones empresariales, juegos, etc. No está especializado en un único dominio.
#
# 3.  **Extenso Ecosistema de Librerías y Frameworks:**
#     *   **"Baterías Incluidas":** Python viene con una biblioteca estándar muy completa.
#     *   **Miles de Librerías de Terceros:** Su comunidad ha desarrollado una cantidad masiva de librerías y frameworks especializados para casi cualquier tarea imaginable:
#         *   **Web:** Django, Flask (para construir sitios web y APIs).
#         *   **Ciencia de Datos:** NumPy, Pandas, Matplotlib, SciPy (para cálculo numérico, manipulación y visualización de datos).
#         *   **Machine Learning e IA:** TensorFlow, Keras, PyTorch, Scikit-learn (para inteligencia artificial y aprendizaje automático).
#         *   **Automatización:** Selenium (para automatización web), paramiko (para SSH).
#         *   **Interfaces Gráficas (GUI):** PyQt, Tkinter, Kivy.
#     *   Esto significa que no tienes que "reinventar la rueda" para muchas funcionalidades.
#
# 4.  **Desarrollo Rápido y Alta Productividad:**
#     *   **Menos Líneas de Código:** Su sintaxis de alto nivel permite expresar conceptos complejos en menos líneas de código en comparación con otros lenguajes (como Java o C++), lo que acelera el proceso de desarrollo.
#     *   **Ciclo de Desarrollo-Prueba Rápido:** Al ser un lenguaje interpretado, no requiere un paso de compilación antes de la ejecución, lo que permite probar los cambios de forma casi instantánea.
#
# 5.  **Multiplataforma:**
#     *   El código Python puede ejecutarse en diferentes sistemas operativos (Windows, macOS, Linux, Unix) con mínimas o ninguna modificación. Esto facilita la implementación y el despliegue de aplicaciones en diversos entornos.
#
# 6.  **Gran Comunidad y Soporte Activo:**
#     *   Python cuenta con una de las comunidades de desarrolladores más grandes y activas del mundo. Esto se traduce en una gran cantidad de recursos, tutoriales, foros, documentación y ayuda disponible, lo cual es invaluable, especialmente para los principiantes.
#
# 7.  **Gratuito y de Código Abierto:**
#     *   Python es gratuito y de código abierto, lo que significa que cualquiera puede usarlo, distribuirlo y modificarlo sin costos de licencia. Esto lo hace accesible para individuos, startups y grandes corporaciones por igual.
#
# 8.  **Integración Sencilla:**
#     *   Python se puede integrar fácilmente con otros lenguajes de programación (como C, C++ o Java) y con diversas tecnologías, bases de datos y servicios, lo que permite aprovechar lo mejor de cada herramienta.
#
# En resumen, la combinación de su **facilidad de uso, versatilidad, la riqueza de su ecosistema y el apoyo de una gran comunidad** hacen de Python una herramienta extremadamente poderosa y la elección preferida para una infinidad de proyectos y desarrolladores en la actualidad.
#
# Respuesta 3 (Resumen): **Python es un lenguaje de programación popular y potente, célebre por su sintaxis legible que facilita el aprendizaje y el desarrollo rápido en múltiples campos, potenciado por un vasto ecosistema de librerías.**
#
# Mensajes en historial: 6

# %%
# Validación B.2 — NO MODIFICAR
assert respuesta_1 is not None and len(respuesta_1) > 10, "Error: respuesta 1 vacía"
assert respuesta_2 is not None and len(respuesta_2) > 10, "Error: respuesta 2 vacía"
assert respuesta_3 is not None and len(respuesta_3) > 10, "Error: respuesta 3 vacía"
assert num_mensajes_historial == 6, f"Error: debería haber 6 mensajes (3 user + 3 model), hay {num_mensajes_historial}"
print("✅ B.2 — Chat multi-turno: CORRECTO")
# Out:
# ✅ B.2 — Chat multi-turno: CORRECTO

# %% [markdown]
# ---
# ## Parte C — Mini RAG (35 puntos)
#
# Construye un sistema RAG sencillo que responda preguntas sobre un corpus dado.

# %%
# !pip install langchain langchain-google-genai langchain-community chromadb -q
# Comentado porque estamos usando una implementación RAG personalizada para evitar problemas de compatibilidad y cuota.

# %%
# Corpus de documentos — NO MODIFICAR
corpus = [
    "Python fue creado por Guido van Rossum y lanzado en 1991. Es un lenguaje de programación de alto nivel, interpretado y de propósito general.",
    "Python destaca por su sintaxis limpia y legible. Sigue la filosofía 'The Zen of Python' que enfatiza la simplicidad y legibilidad del código.",
    "Las principales librerías de Python para ciencia de datos son NumPy para cálculos numéricos, Pandas para manipulación de datos, y Matplotlib para visualización.",
    "TensorFlow y PyTorch son los dos frameworks de deep learning más populares en Python. Keras es una API de alto nivel que funciona sobre TensorFlow.",
    "Django y Flask son los frameworks web más usados en Python. Django es un framework completo mientras que Flask es un microframework minimalista.",
    "Python 3.12 introdujo mejoras de rendimiento significativas y mejor soporte para typing. Python 2 dejó de recibir soporte en enero de 2020.",
    "El gestor de paquetes oficial de Python es pip, y los entornos virtuales se crean con venv o conda. PyPI es el repositorio oficial de paquetes.",
    "Python se utiliza ampliamente en inteligencia artificial, machine learning, automatización, desarrollo web, ciencia de datos y scripting."
]

# %%
# C — Construye tu sistema RAG (Código original de LangChain - Comentado)
# from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
# from langchain_community.vectorstores import Chroma
# from langchain.chains import RetrievalQA

# Tu código aquí:
# 1. Crea embeddings
# embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001", google_api_key=userdata.get("GEMINI_API_KEY"))

# 2. Crea base vectorial con Chroma
# vectorstore = Chroma.from_texts(texts=corpus, embedding=embeddings)

# 3. Configura el LLM (Gemini)
# llm = ChatGoogleGenerativeAI(model="gemini-pro", google_api_key=userdata.get("GEMINI_API_KEY"))

# 4. Crea cadena RAG
# qa_chain = RetrievalQA.from_chain_type(llm=llm, retriever=vectorstore.as_retriever())

# print("RAG system initialized successfully!")

# %% [markdown]
# ### Alternative RAG implementation without LangChain
#
# Since `langchain` might be causing issues, let's implement a simpler RAG system directly using `google.generativeai` for embeddings and the LLM, and `numpy` for vector similarity search. This will give you more control and avoid potential dependency conflicts.
#
# Here are the steps:
# 1.  **Generate Embeddings:** Convert each document in our `corpus` into a numerical vector (embedding) using Gemini's embedding model.
# 2.  **Vector Store (Manual):** Store these embeddings. When a query comes, we'll calculate its embedding and find the most similar documents from our stored embeddings using cosine similarity.
# 3.  **Contextualized Query:** Take the user's question, retrieve the most relevant documents, and combine them into a single prompt for the Gemini LLM.
# 4.  **LLM Answer:** Ask the Gemini LLM to answer the question using the provided context.

# %% [markdown]
# ### Define Corpus and Generate Embeddings for RAG (Re-generating due to previous error)

# %%
corpus = [
    "Python fue creado por Guido van Rossum y lanzado en 1991. Es un lenguaje de programación de alto nivel, interpretado y de propósito general.",
    "Python destaca por su sintaxis limpia y legible. Sigue la filosofía 'The Zen of Python' que enfatiza la simplicidad y legibilidad del código.",
    "Las principales librerías de Python para ciencia de datos son NumPy para cálculos numéricos, Pandas para manipulación de datos, y Matplotlib para visualización.",
    "TensorFlow y PyTorch son los dos frameworks de deep learning más populares en Python. Keras es una API de alto nivel que funciona sobre TensorFlow.",
    "Django y Flask son los frameworks web más usados en Python. Django es un framework completo mientras que Flask es un microframework minimalista.",
    "Python 3.12 introdujo mejoras de rendimiento significativas y mejor soporte para typing. Python 2 dejó de recibir soporte en enero de 2020.",
    "El gestor de paquetes oficial de Python es pip, y los entornos virtuales se crean con venv o conda. PyPI es el repositorio oficial de paquetes.",
    "Python se utiliza ampliamente en inteligencia artificial, machine learning, automatización, desarrollo web, ciencia de datos y scripting."
]

print("Corpus defined successfully!")
# Out:
# Corpus defined successfully!

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import google.generativeai as genai
from google.colab import userdata

genai.configure(api_key=userdata.get("GEMINI_API_KEY"))

# Function to get embeddings in batches to avoid API limits if corpus is large
def get_embeddings(texts):
    embeddings = []
    for text in texts:
        response = genai.embed_content(model="models/gemini-embedding-001", content=text)
        embeddings.append(response['embedding'])
    return np.array(embeddings)

corpus_embeddings = get_embeddings(corpus)
print(f"Generated embeddings for {len(corpus)} documents. Shape: {corpus_embeddings.shape}")
# Out:
# Generated embeddings for 8 documents. Shape: (8, 3072)

# %%
import google.generativeai as genai
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# 2. Manual Vector Store and Similarity Search

def find_relevant_documents(query, corpus_embeddings, corpus, top_k=2):
    query_embedding = get_embeddings([query])[0] # Get embedding for the query

    # Calculate cosine similarity between query and all corpus embeddings
    similarities = cosine_similarity([query_embedding], corpus_embeddings)[0]

    # Get indices of top_k most similar documents
    top_indices = similarities.argsort()[-top_k:][::-1]

    # Retrieve relevant documents
    relevant_docs = [corpus[i] for i in top_indices]
    return relevant_docs

# 3. LLM for contextualized answering
llm_model = genai.GenerativeModel("models/gemini-2.0-flash")

def answer_question_with_rag(question, corpus_embeddings, corpus, llm, top_k=2):
    # Find relevant documents
    context = find_relevant_documents(question, corpus_embeddings, corpus, top_k=top_k)
    context_str = '\n'.join(context)

    # Create a prompt for the LLM with the context
    prompt = f"""Basándote ÚNICAMENTE en la siguiente información, responde a la pregunta. Si la respuesta no está en el contexto, indica que no la sabes.\n\nContexto:\n{context_str}\n\nPregunta: {question}\nRespuesta:"""

    response = llm.generate_content(prompt)
    return response.text

print("RAG functions defined successfully!")
# Out:
# RAG functions defined successfully!

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import google.generativeai as genai
from google.colab import userdata

genai.configure(api_key=userdata.get("GEMINI_API_KEY"))

# 1. Generate Embeddings for the corpus
# The embedding model is used via genai.embed_content directly

# Function to get embeddings in batches to avoid API limits if corpus is large
def get_embeddings(texts):
    embeddings = []
    for text in texts:
        # Correct way to call embed_content
        response = genai.embed_content(model="models/gemini-embedding-001", content=text)
        embeddings.append(response['embedding'])
    return np.array(embeddings)

corpus_embeddings = get_embeddings(corpus)
print(f"Generated embeddings for {len(corpus)} documents. Shape: {corpus_embeddings.shape}")
# Out:
# Generated embeddings for 8 documents. Shape: (8, 3072)

# %%
import google.generativeai as genai

print("Available embedding models for embed_content:")
for m in genai.list_models():
    if "embedContent" in m.supported_generation_methods:
        print(f"- {m.name}")
# Out:
# Available embedding models for embed_content:
# - models/gemini-embedding-001
# - models/gemini-embedding-2-preview
# - models/gemini-embedding-2

# %%
import google.generativeai as genai
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# 2. Manual Vector Store and Similarity Search

def find_relevant_documents(query, corpus_embeddings, corpus, top_k=2):
    query_embedding = get_embeddings([query])[0] # Get embedding for the query

    # Calculate cosine similarity between query and all corpus embeddings
    similarities = cosine_similarity([query_embedding], corpus_embeddings)[0]

    # Get indices of top_k most similar documents
    top_indices = similarities.argsort()[-top_k:][::-1]

    # Retrieve relevant documents
    relevant_docs = [corpus[i] for i in top_indices]
    return relevant_docs

# 3. LLM for contextualized answering
llm_model = genai.GenerativeModel("models/gemini-2.5-flash")

def answer_question_with_rag(question, corpus_embeddings, corpus, llm, top_k=2):
    # Find relevant documents
    context = find_relevant_documents(question, corpus_embeddings, corpus, top_k=top_k)
    context_str = '\n'.join(context)

    # Create a prompt for the LLM with the context
    prompt = f"""Basándote ÚNICAMENTE en la siguiente información, responde a la pregunta. Si la respuesta no está en el contexto, indica que no la sabes.\n\nContexto:\n{context_str}\n\nPregunta: {question}\nRespuesta:"""

    response = llm.generate_content(prompt)
    return response.text

print("RAG functions defined successfully!")
# Out:
# RAG functions defined successfully!

# %%
# C.1 — Responde usando tu RAG (sin Langchain)
pregunta_creador = "¿Quién creó Python?"
respuesta_creador_no_langchain = answer_question_with_rag(pregunta_creador, corpus_embeddings, corpus, llm_model)

print(f"Pregunta: {pregunta_creador}")
print(f"Respuesta: {respuesta_creador_no_langchain}")
# Out:
# Pregunta: ¿Quién creó Python?
# Respuesta: Guido van Rossum

# %%
# Validación C.1 — NO MODIFICAR
assert respuesta_creador_no_langchain is not None, "Error: respuesta vacía"
assert "guido" in respuesta_creador_no_langchain.lower(), f"Error: la respuesta debe mencionar a Guido van Rossum"
print("✅ C.1 — Creador de Python: CORRECTO")
# Out:
# ✅ C.1 — Creador de Python: CORRECTO

# %% [markdown]
# ### C.1 — Pregunta: ¿Quién creó Python? (10 pts) (Sin Langchain)

# %%
# C.1 — Responde usando tu RAG (sin Langchain)
pregunta_creador = "¿Quién creó Python?"
respuesta_creador_no_langchain = answer_question_with_rag(pregunta_creador, corpus_embeddings, corpus, llm_model)

print(f"Pregunta: {pregunta_creador}")
print(f"Respuesta: {respuesta_creador_no_langchain}")
# Out:
# Pregunta: ¿Quién creó Python?
# Respuesta: Guido van Rossum

# %%
import google.generativeai as genai

print("Available Gemini models:")
for m in genai.list_models():
    print(f"- {m.name} (Supported methods: {m.supported_generation_methods})")
# Out:
# Available Gemini models:
# - models/gemini-2.5-flash (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-2.5-pro (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-2.0-flash (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-2.0-flash-001 (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-2.0-flash-lite-001 (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-2.0-flash-lite (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-2.5-flash-preview-tts (Supported methods: ['countTokens', 'generateContent'])
# - models/gemini-2.5-pro-preview-tts (Supported methods: ['countTokens', 'generateContent', 'batchGenerateContent'])
# - models/gemma-3-1b-it (Supported methods: ['generateContent', 'countTokens'])
# - models/gemma-3-4b-it (Supported methods: ['generateContent', 'countTokens'])
# - models/gemma-3-12b-it (Supported methods: ['generateContent', 'countTokens'])
# - models/gemma-3-27b-it (Supported methods: ['generateContent', 'countTokens'])
# - models/gemma-3n-e4b-it (Supported methods: ['generateContent', 'countTokens'])
# - models/gemma-3n-e2b-it (Supported methods: ['generateContent', 'countTokens'])
# - models/gemma-4-26b-a4b-it (Supported methods: ['generateContent', 'countTokens'])
# - models/gemma-4-31b-it (Supported methods: ['generateContent', 'countTokens'])
# - models/gemini-flash-latest (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-flash-lite-latest (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-pro-latest (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-2.5-flash-lite (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-2.5-flash-image (Supported methods: ['generateContent', 'countTokens', 'batchGenerateContent'])
# - models/gemini-3-pro-preview (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-3-flash-preview (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-3.1-pro-preview (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-3.1-pro-preview-customtools (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-3.1-flash-lite-preview (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-3-pro-image-preview (Supported methods: ['generateContent', 'countTokens', 'batchGenerateContent'])
# - models/nano-banana-pro-preview (Supported methods: ['generateContent', 'countTokens', 'batchGenerateContent'])
# - models/gemini-3.1-flash-image-preview (Supported methods: ['generateContent', 'countTokens', 'batchGenerateContent'])
# - models/lyria-3-clip-preview (Supported methods: ['generateContent', 'countTokens'])
# - models/lyria-3-pro-preview (Supported methods: ['generateContent', 'countTokens'])
# - models/gemini-3.1-flash-tts-preview (Supported methods: ['generateContent', 'countTokens', 'batchGenerateContent'])
# - models/gemini-robotics-er-1.5-preview (Supported methods: ['generateContent', 'countTokens'])
# - models/gemini-robotics-er-1.6-preview (Supported methods: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent'])
# - models/gemini-2.5-computer-use-preview-10-2025 (Supported methods: ['generateContent', 'countTokens'])
# - models/deep-research-max-preview-04-2026 (Supported methods: ['generateContent', 'countTokens'])
# - models/deep-research-preview-04-2026 (Supported methods: ['generateContent', 'countTokens'])
# - models/deep-research-pro-preview-12-2025 (Supported methods: ['generateContent', 'countTokens'])
# - models/gemini-embedding-001 (Supported methods: ['embedContent', 'countTextTokens', 'countTokens', 'asyncBatchEmbedContent'])
# - models/gemini-embedding-2-preview (Supported methods: ['embedContent', 'countTextTokens', 'countTokens', 'asyncBatchEmbedContent'])
# - models/gemini-embedding-2 (Supported methods: ['embedContent', 'countTextTokens', 'countTokens', 'asyncBatchEmbedContent'])
# - models/aqa (Supported methods: ['generateAnswer'])
# - models/imagen-4.0-generate-001 (Supported methods: ['predict'])
# - models/imagen-4.0-ultra-generate-001 (Supported methods: ['predict'])
# - models/imagen-4.0-fast-generate-001 (Supported methods: ['predict'])
# - models/veo-2.0-generate-001 (Supported methods: ['predictLongRunning'])
# - models/veo-3.0-generate-001 (Supported methods: ['predictLongRunning'])
# - models/veo-3.0-fast-generate-001 (Supported methods: ['predictLongRunning'])
# - models/veo-3.1-generate-preview (Supported methods: ['predictLongRunning'])
# - models/veo-3.1-fast-generate-preview (Supported methods: ['predictLongRunning'])
# - models/veo-3.1-lite-generate-preview (Supported methods: ['predictLongRunning'])
# - models/gemini-2.5-flash-native-audio-latest (Supported methods: ['countTokens', 'bidiGenerateContent'])
# - models/gemini-2.5-flash-native-audio-preview-09-2025 (Supported methods: ['countTokens', 'bidiGenerateContent'])
# - models/gemini-2.5-flash-native-audio-preview-12-2025 (Supported methods: ['countTokens', 'bidiGenerateContent'])
# - models/gemini-3.1-flash-live-preview (Supported methods: ['bidiGenerateContent'])

# %% [markdown]
# ### C.1 — Pregunta: ¿Quién creó Python? (10 pts)

# %%
# C.1 — Responde usando tu RAG
# pregunta_creador = "¿Quién creó Python?"
# respuesta_creador = answer_question_with_rag(pregunta_creador, corpus_embeddings, corpus, llm_model)

# print(f"Respuesta: {respuesta_creador}")

# C.1 — Responde usando tu RAG (sin Langchain)
pregunta_creador = "¿Quién creó Python?"
respuesta_creador_no_langchain = answer_question_with_rag(pregunta_creador, corpus_embeddings, corpus, llm_model)

print(f"Pregunta: {pregunta_creador}")
print(f"Respuesta: {respuesta_creador_no_langchain}")
# Out:
# Pregunta: ¿Quién creó Python?
# Respuesta: Guido van Rossum

# %%
assert respuesta_creador_no_langchain is not None, "Error: respuesta vacía"
assert "guido" in respuesta_creador_no_langchain.lower(), f"Error: la respuesta debe mencionar a Guido van Rossum"
print("✅ C.1 — Creador de Python: CORRECTO")
# Out:
# ✅ C.1 — Creador de Python: CORRECTO

# %% [markdown]
# ### C.2 — Pregunta: ¿Cuáles son los frameworks de deep learning? (10 pts)

# %%
# C.2 — Pregunta sobre frameworks de deep learning
pregunta_frameworks = "¿Cuáles son los frameworks de deep learning?"
respuesta_frameworks = answer_question_with_rag(pregunta_frameworks, corpus_embeddings, corpus, llm_model)

print(f"Respuesta: {respuesta_frameworks}")
# Out:
# Respuesta: TensorFlow y PyTorch.

# %%
# Validación C.2 — NO MODIFICAR
assert respuesta_frameworks is not None, "Error: respuesta vacía"
resp_lower = respuesta_frameworks.lower()
assert "tensorflow" in resp_lower or "pytorch" in resp_lower, \
    "Error: la respuesta debe mencionar TensorFlow o PyTorch"
print("✅ C.2 — Frameworks DL: CORRECTO")
# Out:
# ✅ C.2 — Frameworks DL: CORRECTO

# %% [markdown]
# ### C.3 — Pregunta: ¿Para qué se usa Python? (15 pts)

# %%
# C.3 — Pregunta sobre usos de Python
pregunta_usos = "¿Para qué se usa Python?"
respuesta_usos = answer_question_with_rag(pregunta_usos, corpus_embeddings, corpus, llm_model)

print(f"Respuesta: {respuesta_usos}")
# Out:
# Respuesta: Python se utiliza en inteligencia artificial, machine learning, automatización, desarrollo web, ciencia de datos y scripting.

# %%
# Validación C.3 — NO MODIFICAR
assert respuesta_usos is not None, "Error: respuesta vacía"
resp_lower = respuesta_usos.lower()
usos_mencionados = sum(1 for uso in ["inteligencia artificial", "machine learning", "web", "datos", "automatización"]
                       if uso in resp_lower or uso.split()[0] in resp_lower)
assert usos_mencionados >= 2, f"Error: la respuesta debe mencionar al menos 2 usos de Python"
print("✅ C.3 — Usos de Python: CORRECTO")
# Out:
# ✅ C.3 — Usos de Python: CORRECTO

# %%
# Este código limpia los metadatos de widgets en el archivo actual
import ipywidgets as widgets
from google.colab import output

# Esto fuerza el reset de la comunicación de widgets
output.clear()

# %% [markdown]
# ---
# ## 📋 Autoevaluación — Responde en Blackboard
#
# Una vez hayas completado las actividades, ve a **Blackboard** y responde el formulario con las siguientes preguntas.
#
# ---
#
# ### Pregunta 1 (Verdadero / Falso)
#
# **La función `pipeline()` de HuggingFace permite usar modelos pre-entrenados con muy pocas líneas de código, sin necesidad de entrenar nada.**
#
# ---
#
# ### Pregunta 2 (Multirespuesta)
#
# **¿Qué tipo de pipeline se usa para clasificar texto en categorías sin haberlo entrenado específicamente para esas categorías?**
#
# - a) `sentiment-analysis`
# - b) `text-generation`
# - c) `zero-shot-classification`
# - d) `question-answering`
#
# ---
#
# ### Pregunta 3 (Verdadero / Falso)
#
# **De las 10 reseñas del ejercicio (Parte A.1), hay exactamente 6 positivas y 4 negativas según el pipeline de sentiment-analysis.**
#
# ---
#
# ### Pregunta 4 (Multirespuesta)
#
# **En un sistema RAG, ¿cuál es la función del paso de "retrieval" (recuperación)?**
#
# - a) Generar la respuesta final con el LLM
# - b) Entrenar el modelo con los documentos
# - c) Buscar los documentos más relevantes de la base de conocimiento
# - d) Tokenizar el texto de entrada
#
# ---
#
# ### Pregunta 5 (Verdadero / Falso)
#
# **La API de chat de Gemini mantiene el contexto de la conversación a lo largo de múltiples mensajes (chat multi-turno).**
#
# ---
#
# ### Pregunta 6 (Multirespuesta)
#
# **En un sistema RAG, ¿qué componente almacena los embeddings vectoriales para la búsqueda por similitud?**
#
# - a) El LLM (Large Language Model)
# - b) El tokenizer
# - c) La base de datos vectorial (ej: Chroma)
# - d) El prompt template
#
# ---
#
# ### Pregunta 7 (Verdadero / Falso)
#
# **Zero-shot classification requiere hacer fine-tuning del modelo con nuestras categorías específicas antes de poder usarlo.**
#
# ---
#
# ### Pregunta 8 (Multirespuesta)
#
# **Si hacemos 3 preguntas en un chat multi-turno con Gemini (Parte B.2), ¿cuántos mensajes tiene el historial del chat?**
#
# - a) 3
# - b) 4
# - c) 6
# - d) 9
